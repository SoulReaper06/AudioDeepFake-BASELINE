# %%
import os
import numpy as np
import librosa
import tensorflow as tf
from tensorflow.keras.initializers import GlorotUniform
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import MaxPooling2D, Dropout, Activation, TimeDistributed
from tensorflow.keras.layers import BatchNormalization  # Updated import

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten, Lambda 
from tensorflow.keras.layers import LeakyReLU

import numpy as np
from sklearn.model_selection import train_test_split

# Update to TensorFlow 2.x syntax
import keras
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K

# Change the import for GlobalAveragePooling1D to GlobalAveragePooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D

# %%
# Set your file paths and constants
TRAINING_LABEL = "/data/common_source/datasets/asvpoof-2019-dataset/PA/PA/ASVspoof2019_PA_cm_protocols/ASVspoof2019.PA.cm.train.trn.txt"
TRAINING_DATA = (
    "/data/common_source/datasets/asvpoof-2019-dataset/PA/PA/ASVspoof2019_PA_train/flac"
)
VALIDATION_DATA = (
    "/data/common_source/datasets/asvpoof-2019-dataset/PA/PA/ASVspoof2019_PA_dev/flac"
)
VALIDATION_LABEL = "/data/common_source/datasets/asvpoof-2019-dataset/PA/PA/ASVspoof2019_PA_cm_protocols/ASVspoof2019.PA.cm.dev.trl.txt"
SAMPLE_RATE = 16000  # Adjust if your sample rate is different
DURATION = 3  # Adjust the duration of your audio samples
N_MFCC = 128  # Adjust the number of mel filters
max_time_steps = 109

# %%
def load_and_preprocess_audio(file_path,n_fft=512, hop_length=160, win_length=512,max_length=300):
    ''' Given an audio signal, computes power (or log power) spectrogram '''
    # Load the audio signal
    y, _ = librosa.load(file_path,sr=16000)

    # Compute the short-time Fourier transform (STFT)
    D = np.abs(librosa.stft(y=y, n_fft=n_fft, hop_length=hop_length, win_length=win_length))**2

    # Ensure the spectrogram is not all zeros
    D = np.maximum(D, 1e-5)

    # Take the logarithm
    D = np.log(D)

    # Ensure that the LFCC arrays have the same shape
    if D.shape[1] < max_length:
        # If shorter, pad with zeros
        pad_width = ((0, 0), (0, max_length - D.shape[1]))
        D = np.pad(D, pad_width, mode='constant', constant_values=0)
    elif D.shape[1] > max_length:
        # If longer, truncate
        D = D[:, :max_length]

    return D.T

# %%
file_path1 = "/data/common_source/datasets/asvpoof-2019-dataset/PA/PA/ASVspoof2019_PA_train/flac/PA_T_0023581.flac"
file_path2 = "/data/common_source/datasets/asvpoof-2019-dataset/PA/PA/ASVspoof2019_PA_train/flac/PA_T_0030329.flac"

lfcc1 = load_and_preprocess_audio(file_path1)
lfcc2 = load_and_preprocess_audio(file_path2)

print(lfcc1.shape)
print(lfcc2.shape)
# Out:
# (300, 257)
# (300, 257)

# %%
from pydub import AudioSegment
def get_duration_pydub(file_path):
   audio_file = AudioSegment.from_file(file_path)
   duration = audio_file.duration_seconds
   return duration
file_path = '/data/common_source/datasets/asvpoof-2019-dataset/PA/PA/ASVspoof2019_PA_train/flac/PA_T_0023581.flac'
duration = get_duration_pydub(file_path)
print(f"Duration: {duration:.2f} seconds")
# Out:
# Duration: 4.31 seconds

# %%
# Load labels for training Data
train_labels = {}

with open(TRAINING_LABEL, 'r') as label_file:
    lines = label_file.readlines()

for line in lines:
    parts = line.strip().split()
    file_name = parts[1]
    label = 1 if parts[-1] == "bonafide" else 0
    train_labels[file_name] = label

X = []
y = []

for file_name, label in train_labels.items():
    file_path = os.path.join(TRAINING_DATA, file_name + ".flac")

    # Use the preprocess_data function with max_length
    lfcc = load_and_preprocess_audio(file_path)

    X.append(lfcc)
    y.append(label)

X = np.array(X)
y = np.array(y)

# %%
# Print out the shapes for debugging
print("Shape of X before reshape:", X.shape)
print("Shape of y before reshape:", y.shape)

X_reshaped = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)

print("Shape of X after reshape:", X_reshaped.shape)
# Out:
# Shape of X before reshape: (54000, 300, 257)
# Shape of y before reshape: (54000,)
# Shape of X after reshape: (54000, 300, 257, 1)

# %%
# Load labels for evaluation Data
eval_X = []
eval_y = []

with open(VALIDATION_LABEL, 'r') as eval_label_file:
    eval_lines = eval_label_file.readlines()

eval_labels = {}

for line in eval_lines:
    parts = line.strip().split()
    file_name = parts[1]
    label = 1 if parts[-1] == "bonafide" else 0
    eval_labels[file_name] = label

for file_name, label in eval_labels.items():
    file_path = os.path.join(VALIDATION_DATA, file_name + ".flac")

        # Use the preprocess_data function
    lfcc = load_and_preprocess_audio(file_path)

    eval_X.append(lfcc)
    eval_y.append(label)


eval_X = np.array(eval_X)
eval_y = np.array(eval_y)

# %%
# Print out the shapes for debugging
print("Shape of eval_X before reshape:", eval_X.shape)
print("Shape of eval_y before reshape:", eval_y.shape)

eval_X_reshaped = eval_X.reshape(eval_X.shape[0], eval_X.shape[1], eval_X.shape[2], 1)

print("Shape of X after reshape:", eval_X_reshaped.shape)
# Out:
# Shape of eval_X before reshape: (29700, 300, 257)
# Shape of eval_y before reshape: (29700,)
# Shape of X after reshape: (29700, 300, 257, 1)

# %%
def init_weights():
    initializer = GlorotUniform()
    return initializer

# %%
def apply_activation(x):
    y = BatchNormalization()(x)
    y = Activation('relu')(y)
    return x

# %%
# Define constants
input_shape = (X.shape[1], X.shape[2], 1)  # LFCC features have 13 dimensions

def lcnn_model(input_shape):
    x = Sequential()

    # Convolutional layers
    inputs = Input(shape=input_shape)

    x = Conv2D(16, (5, 5), padding='same', kernel_initializer=init_weights())(inputs)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = Conv2D(16, (1, 1), padding='same', kernel_initializer=init_weights())(x)
    x = apply_activation(x)
    x = Conv2D(24, (3, 3), padding='same', kernel_initializer=init_weights())(x)
    x = apply_activation(x)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = Conv2D(32, (1, 1), padding='same', kernel_initializer=init_weights())(x)
    x = apply_activation(x)
    x = Conv2D(32, (3, 3), padding='same', kernel_initializer=init_weights())(x)
    x = apply_activation(x)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = Conv2D(32, (1, 1), padding='same', kernel_initializer=init_weights())(x)
    x = apply_activation(x)
    x = Conv2D(16, (3, 3), padding='same', kernel_initializer=init_weights())(x)
    x = apply_activation(x)
    x = MaxPooling2D(pool_size=(2,2))(x)


    x = Conv2D(16, (1, 1), padding='same', kernel_initializer=init_weights())(x)
    x = apply_activation(x)
    x = Conv2D(16, (3, 3), padding='same', kernel_initializer=init_weights())(x)
    x = apply_activation(x)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = Flatten()(x)
    x = Dropout(0.5)(x)
    x = Dense(32, kernel_initializer=init_weights())(x)
    x = apply_activation(x)

    x = Dropout(0.5)(x)
    x = Dense(1,kernel_initializer=init_weights())(x)
    x = BatchNormalization()(x)
    x = Activation('sigmoid')(x)

    model = Model(inputs=inputs, outputs=x)
    return model

# %%
model = lcnn_model(input_shape)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# 2023-11-28 15:19:19.464275: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-28 15:19:20.262320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22834 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2023-11-28 15:19:20.262932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22758 MB memory:  -> device: 1, name: NVIDIA TITAN RTX, pci bus id: 0000:68:00.0, compute capability: 7.5

# %%
# Display the model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 300, 257, 1)]     0
#
#  conv2d (Conv2D)             (None, 300, 257, 16)      416
#
#  max_pooling2d (MaxPooling2D  (None, 150, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 150, 128, 16)      272
#
#  conv2d_2 (Conv2D)           (None, 150, 128, 24)      3480
#
#  max_pooling2d_1 (MaxPooling  (None, 75, 64, 24)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 75, 64, 32)        800
#
#  conv2d_4 (Conv2D)           (None, 75, 64, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 37, 32, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 37, 32, 32)        1056
#
#  conv2d_6 (Conv2D)           (None, 37, 32, 16)        4624
#
#  max_pooling2d_3 (MaxPooling  (None, 18, 16, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 18, 16, 16)        272
#
#  conv2d_8 (Conv2D)           (None, 18, 16, 16)        2320
#
#  max_pooling2d_4 (MaxPooling  (None, 9, 8, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dropout (Dropout)           (None, 1152)              0
#
#  dense (Dense)               (None, 32)                36896
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
#  batch_normalization_9 (Batc  (None, 1)                4
#  hNormalization)
#
#  activation_9 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 59,421
# Trainable params: 59,419
# Non-trainable params: 2
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_reshaped, y, test_size=0.2, random_state=42)

# Define a model checkpoint to save the best weights during training
checkpoint = ModelCheckpoint('models/model_PA_new.h5', monitor='val_loss', save_best_only=True)

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(eval_X_reshaped, eval_y), epochs=100, batch_size=32, callbacks=[checkpoint])
# Out:
# 2023-11-28 15:19:23.839996: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 13322880000 exceeds 10% of free system memory.
# 2023-11-28 15:19:32.872083: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 13322880000 exceeds 10% of free system memory.
# Epoch 1/100
# 2023-11-28 15:19:41.588263: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
# 2023-11-28 15:19:42.091545: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 1348/1350 [============================>.] - ETA: 0s - loss: 0.4977 - accuracy: 0.7894
# 2023-11-28 15:20:05.640694: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 9159480000 exceeds 10% of free system memory.
# 2023-11-28 15:20:11.865690: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 9159480000 exceeds 10% of free system memory.
# 1350/1350 [==============================] - 45s 32ms/step - loss: 0.4975 - accuracy: 0.7897 - val_loss: 0.3748 - val_accuracy: 0.8370
# Epoch 2/100
# 1350/1350 [==============================] - 31s 23ms/step - loss: 0.2876 - accuracy: 0.9081 - val_loss: 0.2788 - val_accuracy: 0.8596
# Epoch 3/100
# 1350/1350 [==============================] - 31s 23ms/step - loss: 0.2161 - accuracy: 0.9170 - val_loss: 0.3197 - val_accuracy: 0.9062
# Epoch 4/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.1763 - accuracy: 0.9302 - val_loss: 0.3394 - val_accuracy: 0.8342
# Epoch 5/100
# 1350/1350 [==============================] - 31s 23ms/step - loss: 0.1410 - accuracy: 0.9453 - val_loss: 0.1652 - val_accuracy: 0.9534
# Epoch 6/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.1161 - accuracy: 0.9570 - val_loss: 0.1251 - val_accuracy: 0.9520
# Epoch 7/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.1066 - accuracy: 0.9612 - val_loss: 0.1314 - val_accuracy: 0.9627
# Epoch 8/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0966 - accuracy: 0.9645 - val_loss: 0.1809 - val_accuracy: 0.9203
# Epoch 9/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0907 - accuracy: 0.9670 - val_loss: 0.1005 - val_accuracy: 0.9646
# Epoch 10/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0875 - accuracy: 0.9675 - val_loss: 0.3207 - val_accuracy: 0.8758
# Epoch 11/100
# 1350/1350 [==============================] - 31s 23ms/step - loss: 0.0840 - accuracy: 0.9695 - val_loss: 0.3216 - val_accuracy: 0.8739
# Epoch 12/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0796 - accuracy: 0.9710 - val_loss: 0.0951 - val_accuracy: 0.9654
# Epoch 13/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0753 - accuracy: 0.9718 - val_loss: 0.1147 - val_accuracy: 0.9551
# Epoch 14/100
# 1350/1350 [==============================] - 32s 24ms/step - loss: 0.0725 - accuracy: 0.9725 - val_loss: 0.3382 - val_accuracy: 0.8827
# Epoch 15/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0739 - accuracy: 0.9720 - val_loss: 0.0922 - val_accuracy: 0.9666
# Epoch 16/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0686 - accuracy: 0.9743 - val_loss: 0.1478 - val_accuracy: 0.9401
# Epoch 17/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0694 - accuracy: 0.9744 - val_loss: 0.1889 - val_accuracy: 0.9295
# Epoch 18/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0662 - accuracy: 0.9756 - val_loss: 0.1603 - val_accuracy: 0.9368
# Epoch 19/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0603 - accuracy: 0.9785 - val_loss: 0.2382 - val_accuracy: 0.9051
# Epoch 20/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0642 - accuracy: 0.9767 - val_loss: 0.0906 - val_accuracy: 0.9676
# Epoch 21/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0610 - accuracy: 0.9776 - val_loss: 0.0868 - val_accuracy: 0.9685
# Epoch 22/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0567 - accuracy: 0.9792 - val_loss: 0.0810 - val_accuracy: 0.9700
# Epoch 23/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0582 - accuracy: 0.9788 - val_loss: 0.1307 - val_accuracy: 0.9528
# Epoch 24/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0568 - accuracy: 0.9796 - val_loss: 0.2284 - val_accuracy: 0.9223
# Epoch 25/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0523 - accuracy: 0.9815 - val_loss: 0.2326 - val_accuracy: 0.9199
# Epoch 26/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0542 - accuracy: 0.9805 - val_loss: 0.1044 - val_accuracy: 0.9642
# Epoch 27/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0548 - accuracy: 0.9786 - val_loss: 0.1068 - val_accuracy: 0.9605
# Epoch 28/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0499 - accuracy: 0.9814 - val_loss: 0.0875 - val_accuracy: 0.9703
# Epoch 29/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0494 - accuracy: 0.9823 - val_loss: 0.1160 - val_accuracy: 0.9602
# Epoch 30/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0535 - accuracy: 0.9797 - val_loss: 0.1262 - val_accuracy: 0.9539
# Epoch 31/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0507 - accuracy: 0.9820 - val_loss: 0.1122 - val_accuracy: 0.9597
# Epoch 32/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0477 - accuracy: 0.9826 - val_loss: 0.0900 - val_accuracy: 0.9680
# Epoch 33/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0493 - accuracy: 0.9816 - val_loss: 0.0854 - val_accuracy: 0.9689
# Epoch 34/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0479 - accuracy: 0.9823 - val_loss: 0.0806 - val_accuracy: 0.9711
# Epoch 35/100
# 1350/1350 [==============================] - 32s 24ms/step - loss: 0.0447 - accuracy: 0.9838 - val_loss: 0.0721 - val_accuracy: 0.9730
# Epoch 36/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0475 - accuracy: 0.9822 - val_loss: 0.0773 - val_accuracy: 0.9721
# Epoch 37/100
# 1350/1350 [==============================] - 32s 24ms/step - loss: 0.0461 - accuracy: 0.9832 - val_loss: 0.0794 - val_accuracy: 0.9719
# Epoch 38/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0450 - accuracy: 0.9834 - val_loss: 0.1042 - val_accuracy: 0.9640
# Epoch 39/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0438 - accuracy: 0.9840 - val_loss: 0.2449 - val_accuracy: 0.9197
# Epoch 40/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0417 - accuracy: 0.9856 - val_loss: 0.0875 - val_accuracy: 0.9694
# Epoch 41/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0447 - accuracy: 0.9831 - val_loss: 0.0997 - val_accuracy: 0.9679
# Epoch 42/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0441 - accuracy: 0.9832 - val_loss: 0.0773 - val_accuracy: 0.9740
# Epoch 43/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0401 - accuracy: 0.9850 - val_loss: 0.1468 - val_accuracy: 0.9493
# Epoch 44/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0404 - accuracy: 0.9853 - val_loss: 0.0743 - val_accuracy: 0.9729
# Epoch 45/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0438 - accuracy: 0.9838 - val_loss: 0.1924 - val_accuracy: 0.9406
# Epoch 46/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0399 - accuracy: 0.9855 - val_loss: 0.0854 - val_accuracy: 0.9708
# Epoch 47/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0391 - accuracy: 0.9858 - val_loss: 0.1255 - val_accuracy: 0.9575
# Epoch 48/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0420 - accuracy: 0.9847 - val_loss: 0.1877 - val_accuracy: 0.9396
# Epoch 49/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0389 - accuracy: 0.9855 - val_loss: 0.0889 - val_accuracy: 0.9701
# Epoch 50/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0365 - accuracy: 0.9871 - val_loss: 0.1015 - val_accuracy: 0.9673
# Epoch 51/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0382 - accuracy: 0.9860 - val_loss: 0.0808 - val_accuracy: 0.9709
# Epoch 52/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0373 - accuracy: 0.9861 - val_loss: 0.1039 - val_accuracy: 0.9668
# Epoch 53/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0385 - accuracy: 0.9856 - val_loss: 0.1014 - val_accuracy: 0.9673
# Epoch 54/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0388 - accuracy: 0.9856 - val_loss: 0.0780 - val_accuracy: 0.9722
# Epoch 55/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0377 - accuracy: 0.9858 - val_loss: 0.0916 - val_accuracy: 0.9695
# Epoch 56/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0384 - accuracy: 0.9856 - val_loss: 0.1084 - val_accuracy: 0.9645
# Epoch 57/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0380 - accuracy: 0.9856 - val_loss: 0.1347 - val_accuracy: 0.9602
# Epoch 58/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0372 - accuracy: 0.9864 - val_loss: 0.0877 - val_accuracy: 0.9709
# Epoch 59/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0363 - accuracy: 0.9870 - val_loss: 0.0960 - val_accuracy: 0.9691
# Epoch 60/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0362 - accuracy: 0.9866 - val_loss: 0.0932 - val_accuracy: 0.9690
# Epoch 61/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0369 - accuracy: 0.9864 - val_loss: 0.0945 - val_accuracy: 0.9690
# Epoch 62/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0360 - accuracy: 0.9864 - val_loss: 0.1259 - val_accuracy: 0.9609
# Epoch 63/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0357 - accuracy: 0.9871 - val_loss: 0.0935 - val_accuracy: 0.9696
# Epoch 64/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0368 - accuracy: 0.9860 - val_loss: 0.2125 - val_accuracy: 0.9411
# Epoch 65/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0354 - accuracy: 0.9871 - val_loss: 0.1640 - val_accuracy: 0.9555
# Epoch 66/100
# 1350/1350 [==============================] - 32s 24ms/step - loss: 0.0348 - accuracy: 0.9876 - val_loss: 0.0887 - val_accuracy: 0.9697
# Epoch 67/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0330 - accuracy: 0.9884 - val_loss: 0.1414 - val_accuracy: 0.9598
# Epoch 68/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0337 - accuracy: 0.9873 - val_loss: 0.1175 - val_accuracy: 0.9661
# Epoch 69/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0364 - accuracy: 0.9862 - val_loss: 0.0900 - val_accuracy: 0.9711
# Epoch 70/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0302 - accuracy: 0.9895 - val_loss: 0.1808 - val_accuracy: 0.9484
# Epoch 71/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0344 - accuracy: 0.9874 - val_loss: 0.1244 - val_accuracy: 0.9640
# Epoch 72/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0316 - accuracy: 0.9885 - val_loss: 0.1831 - val_accuracy: 0.9495
# Epoch 73/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0336 - accuracy: 0.9884 - val_loss: 0.1097 - val_accuracy: 0.9637
# Epoch 74/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0322 - accuracy: 0.9881 - val_loss: 0.2074 - val_accuracy: 0.9459
# Epoch 75/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0314 - accuracy: 0.9888 - val_loss: 0.1899 - val_accuracy: 0.9470
# Epoch 76/100
# 1350/1350 [==============================] - 32s 24ms/step - loss: 0.0309 - accuracy: 0.9889 - val_loss: 0.1230 - val_accuracy: 0.9627
# Epoch 77/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0310 - accuracy: 0.9885 - val_loss: 0.1774 - val_accuracy: 0.9554
# Epoch 78/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0303 - accuracy: 0.9895 - val_loss: 0.0960 - val_accuracy: 0.9711
# Epoch 79/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0311 - accuracy: 0.9891 - val_loss: 0.1208 - val_accuracy: 0.9654
# Epoch 80/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0299 - accuracy: 0.9893 - val_loss: 0.2244 - val_accuracy: 0.9407
# Epoch 81/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0310 - accuracy: 0.9888 - val_loss: 0.1233 - val_accuracy: 0.9648
# Epoch 82/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0308 - accuracy: 0.9887 - val_loss: 0.2533 - val_accuracy: 0.9343
# Epoch 83/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0308 - accuracy: 0.9890 - val_loss: 0.2371 - val_accuracy: 0.9365
# Epoch 84/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0295 - accuracy: 0.9898 - val_loss: 0.1089 - val_accuracy: 0.9668
# Epoch 85/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0334 - accuracy: 0.9874 - val_loss: 0.1678 - val_accuracy: 0.9524
# Epoch 86/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0317 - accuracy: 0.9881 - val_loss: 0.0974 - val_accuracy: 0.9699
# Epoch 87/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0297 - accuracy: 0.9890 - val_loss: 0.1022 - val_accuracy: 0.9699
# Epoch 88/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0292 - accuracy: 0.9894 - val_loss: 0.2698 - val_accuracy: 0.9352
# Epoch 89/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0275 - accuracy: 0.9900 - val_loss: 0.0949 - val_accuracy: 0.9705
# Epoch 90/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0301 - accuracy: 0.9887 - val_loss: 0.2159 - val_accuracy: 0.9451
# Epoch 91/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0307 - accuracy: 0.9886 - val_loss: 0.1563 - val_accuracy: 0.9586
# Epoch 92/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0278 - accuracy: 0.9900 - val_loss: 0.1123 - val_accuracy: 0.9673
# Epoch 93/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0270 - accuracy: 0.9903 - val_loss: 0.1221 - val_accuracy: 0.9648
# Epoch 94/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0277 - accuracy: 0.9897 - val_loss: 0.1173 - val_accuracy: 0.9674
# Epoch 95/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0292 - accuracy: 0.9893 - val_loss: 0.2251 - val_accuracy: 0.9403
# Epoch 96/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0288 - accuracy: 0.9897 - val_loss: 0.1142 - val_accuracy: 0.9696
# Epoch 97/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0282 - accuracy: 0.9896 - val_loss: 0.1143 - val_accuracy: 0.9686
# Epoch 98/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0278 - accuracy: 0.9902 - val_loss: 0.1839 - val_accuracy: 0.9538
# Epoch 99/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0288 - accuracy: 0.9895 - val_loss: 0.1357 - val_accuracy: 0.9626
# Epoch 100/100
# 1350/1350 [==============================] - 32s 23ms/step - loss: 0.0282 - accuracy: 0.9900 - val_loss: 0.2850 - val_accuracy: 0.9315

# %%
# # Evaluate the model on the test set
loss, accuracy = model.evaluate(X_val, y_val)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy * 100:.2f}%")

# Evaluate the model on the separate evaluation dataset
eval_loss, eval_accuracy = model.evaluate(eval_X_reshaped, eval_y)
print(
    f"Evaluation Loss: {eval_loss:.4f}, Evaluation Accuracy: {eval_accuracy * 100:.2f}%"
)
# Out:
# 2023-11-28 16:12:46.480548: W tensorflow/core/common_runtime/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.10GiB (rounded to 3330720000)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-11-28 16:12:46.480629: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] BFCAllocator dump for GPU_0_bfc
# 2023-11-28 16:12:46.480660: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (256): 	Total Chunks: 137, Chunks in use: 136. 34.2KiB allocated for chunks. 34.0KiB in use in bin. 7.1KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480680: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480700: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1024): 	Total Chunks: 9, Chunks in use: 9. 10.8KiB allocated for chunks. 10.8KiB in use in bin. 10.1KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480718: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2048): 	Total Chunks: 4, Chunks in use: 4. 11.0KiB allocated for chunks. 11.0KiB in use in bin. 10.6KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480735: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4096): 	Total Chunks: 3, Chunks in use: 3. 12.0KiB allocated for chunks. 12.0KiB in use in bin. 12.0KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480753: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8192): 	Total Chunks: 5, Chunks in use: 5. 54.0KiB allocated for chunks. 54.0KiB in use in bin. 54.0KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480771: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16384): 	Total Chunks: 4, Chunks in use: 4. 71.5KiB allocated for chunks. 71.5KiB in use in bin. 67.5KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480789: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 108.0KiB allocated for chunks. 108.0KiB in use in bin. 108.0KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480804: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480823: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (131072): 	Total Chunks: 5, Chunks in use: 4. 911.2KiB allocated for chunks. 761.5KiB in use in bin. 664.0KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480854: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (262144): 	Total Chunks: 1, Chunks in use: 1. 337.5KiB allocated for chunks. 337.5KiB in use in bin. 337.5KiB client-requested in use in bin.
# 2023-11-28 16:12:46.480868: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480881: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480894: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480907: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480920: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8388608): 	Total Chunks: 1, Chunks in use: 0. 9.20MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480933: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480945: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480958: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480975: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-28 16:12:46.480991: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (268435456): 	Total Chunks: 3, Chunks in use: 2. 22.29GiB allocated for chunks. 20.94GiB in use in bin. 20.94GiB client-requested in use in bin.
# 2023-11-28 16:12:46.481007: I tensorflow/core/common_runtime/bfc_allocator.cc:1050] Bin for
I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 6 Chunks of size 1024 totalling 6.0KiB
# 2023-11-28 16:12:46.483060: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-11-28 16:12:46.483073: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 1792 totalling 3.5KiB
# 2023-11-28 16:12:46.483085: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 2048 totalling 2.0KiB
# 2023-11-28 16:12:46.483097: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 3072 totalling 9.0KiB
# 2023-11-28 16:12:46.483110: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 4096 totalling 12.0KiB
# 2023-11-28 16:12:46.483122: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 9216 totalling 27.0KiB
# 2023-11-28 16:12:46.483136: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 13824 totalling 27.0KiB
# 2023-11-28 16:12:46.483168: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 16896 totalling 16.5KiB
# 2023-11-28 16:12:46.483182: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 18432 totalling 36.0KiB
# 2023-11-28 16:12:46.483195: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 19456 totalling 19.0KiB
# 2023-11-28 16:12:46.483208: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 36864 totalling 108.0KiB
# 2023-11-28 16:12:46.483221: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 147456 totalling 288.0KiB
# 2023-11-28 16:12:46.483234: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 237824 totalling 232.2KiB
# 2023-11-28 16:12:46.483247: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 247040 totalling 241.2KiB
# 2023-11-28 16:12:46.483260: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 345600 totalling 337.5KiB
# 2023-11-28 16:12:46.483273: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 9159480064 totalling 8.53GiB
# 2023-11-28 16:12:46.483286: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 13322880000 totalling 12.41GiB
# 2023-11-28 16:12:46.483299: I tensorflow/core/common_runtime/bfc_allocator.cc:1095] Sum Total of in-use chunks: 20.94GiB
# 2023-11-28 16:12:46.483311: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] total_region_allocated_bytes_: 23943577600 memory_limit_: 23943577600 available bytes: 0 curr_region_allocation_bytes_: 47887155200
# 2023-11-28 16:12:46.483330: I tensorflow/core/common_runtime/bfc_allocator.cc:1103] Stats:
# Limit:                     23943577600
# InUse:                     22483793920
# MaxInUse:                  23002831872
# NumAllocs:                    26980809
# MaxAllocSize:              13322880000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-11-28 16:12:46.483364: W tensorflow/core/common_runtime/bfc_allocator.cc:491] **********************************************************************************************______
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /home/jonat/AudioDeepFake_Baseline_Test/PA/LCNN-LFCC-PA.ipynb Cell 17 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B172.30.55.145/home/jonat/AudioDeepFake_Baseline_Test/PA/LCNN-LFCC-PA.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # # Evaluate the model on the test set
# ----> <a href='vscode-notebook-cell://ssh-remote%2B172.30.55.145/home/jonat/AudioDeepFake_Baseline_Test/PA/LCNN-LFCC-PA.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> loss, accuracy = model.evaluate(X_val, y_val)
#       <a href='vscode-notebook-cell://ssh-remote%2B172.30.55.145/home/jonat/AudioDeepFake_Baseline_Test/PA/LCNN-LFCC-PA.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy * 100:.2f}%")
#       <a href='vscode-notebook-cell://ssh-remote%2B172.30.55.145/home/jonat/AudioDeepFake_Baseline_Test/PA/LCNN-LFCC-PA.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> # Evaluate the model on the separate evaluation dataset
#
# File ~/miniconda3/envs/ASV/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/miniconda3/envs/ASV/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Example usage
file_path = '/home/jonat/test2.wav'
lfcc_features = load_and_preprocess_audio(file_path)

# Reshape the LFCC features to match the input shape of the model
lfcc_features = np.expand_dims(lfcc_features, axis=0)
lfcc_features = np.expand_dims(lfcc_features, axis=-1)  # Add channel dimension

# Make predictions
predictions = model.predict(lfcc_features)
print(predictions)
# Out:
# 1/1 [==============================] - 0s 192ms/step
# [[0.00462059]]

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
